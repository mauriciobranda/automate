# %%
import pandas as pd

# %%
flags = pd.read_csv("/Users/mauriciobrandalise/Projects/livro_pandasPy/pandas/flags.csv")

# %%
flags[['name', 'population']]
# Out:
#                name  population
# 0       Afghanistan          16
# 1           Albania           3
# 2           Algeria          20
# 3    American-Samoa           0
# 4           Andorra           0
# ..              ...         ...
# 189   Western-Samoa           0
# 190      Yugoslavia          22
# 191           Zaire          28
# 192          Zambia           6
# 193        Zimbabwe           8
#
# [194 rows x 2 columns]

# %%
flags.tail()
# Out:
#               name  landmass  zone  area  population  language  religion  \
# 189  Western-Samoa         6     3     3           0         1         1
# 190     Yugoslavia         3     1   256          22         6         6
# 191          Zaire         4     2   905          28        10         5
# 192         Zambia         4     2   753           6        10         5
# 193       Zimbabwe         4     2   391           8        10         5
#
#      bars  stripes  colours  ...  saltires  quarters  sunstars  crescent  \
# 189     0        0        3  ...         0         1         5         0
# 190     0        3        4  ...         0         0         1         0
# 191     0        0        4  ...         0         0         0         0
# 192     3        0        4  ...         0         0         0         0
# 193     0        7        5  ...         0         0         1         0
#
#      triangle  icon  animate text  topleft  botright
# ...

# %%
verde = flags['green']

# %%
verde
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      0
#       ..
# 189    0
# 190    0
# 191    1
# 192    1
# 193    1
# Name: green, Length: 194, dtype: int64

# %%
vermelho = flags['red']

# %%
azul = flags['blue']
flags.iloc[187] #procura index i
# Out:
# name          Venezuela
# landmass              2
# zone                  4
# area                912
# population           15
# language              2
# religion              0
# bars                  0
# stripes               3
# colours               7
# red                   1
# green                 1
# blue                  1
# gold                  1
# white                 1
# black                 1
# orange                1
# mainhue             red
# circles               0
# crosses               0
# saltires              0
# quarters              0
# sunstars              7
# crescent              0
# triangle              0
# icon                  1
# animate               1
# text                  0
# topleft            gold
# botright            red
# Name: 187, dtype: object

# %%
amarelo = flags['gold']
branco = flags['white']

# %%
soma = verde + amarelo + azul + branco
somaVerdeBranco = verde + branco
temVerdeBranco = (soma==2)

# %%
tem_todas = (soma==4)

# %%
print('países com verde, amarelo, azul e branco:')
print(flags[tem_todas.values]['name'])
# Out:
# países com verde, amarelo, azul e branco:
# 17                       Belize
# 19                      Bermuda
# 23                       Brazil
# 24         British-Virgin-Isles
# 26                     Bulgaria
# 33               Cayman-Islands
# 34     Central-African-Republic
# 48                     Dominica
# 56           Falklands-Malvinas
# 57                         Fiji
# 71                         Guam
# 78                    Hong-Kong
# 116                  Montserrat
# 135                     Parguay
# 139                    Portugal
# 142                     Romania
# 151             Soloman-Islands
# 158                   St-Helena
# 161                  St-Vincent
# 176         Turks-Cocos-Islands
# 182             US-Virgin-Isles
# 187                   Venezuela
# Name: name, dtype: object

# %%
flags.query('green>0')
# Out:
#             name  landmass  zone  area  population  language  religion  bars  \
# 0    Afghanistan         5     1   648          16        10         2     0
# 2        Algeria         4     1  2388          20         8         2     2
# 14    Bangladesh         5     1   143          90         6         2     0
# 17        Belize         1     4    23           0         1         1     0
# 18         Benin         4     1   113           3         3         5     0
# ..           ...       ...   ...   ...         ...       ...       ...   ...
# 185      Vanuatu         6     2    15           0         6         1     0
# 187    Venezuela         2     4   912          15         2         0     0
# 191        Zaire         4     2   905          28        10         5     0
# 192       Zambia         4     2   753           6        10         5     3
# 193     Zimbabwe         4     2   391           8        10         5     0
#
# ...

# %%
print(flags[temVerdeBranco.values]['name'])
# Out:
# 2            Algeria
# 4            Andorra
# 6           Anguilla
# 8          Argentina
# 10         Australia
#            ...
# 183              USA
# 185          Vanuatu
# 186     Vatican-City
# 189    Western-Samoa
# 191            Zaire
# Name: name, Length: 104, dtype: object

# %%
paises_low_territory = flags.query('area<10')

# %%
'''2. continente : código do continente.
1=América do Norte e América Central;
2=América do Sul;
3=Europa;
4=África;
5=Ásia'''
# Out:
# '2. continente : código do continente.\n1=América do Norte e América Central;\n2=América do Sul;\n3=Europa;\n4=África;\n5=Ásia'

# %%
paises_low_territory[['name','population']]
# Out:
#                      name  population
# 3          American-Samoa           0
# 4                 Andorra           0
# 6                Anguilla           0
# 7         Antigua-Barbuda           0
# 13                Bahrain           0
# 15               Barbados           0
# 19                Bermuda           0
# 24   British-Virgin-Isles           0
# 25                 Brunei           0
# 32     Cape-Verde-Islands           0
# 33         Cayman-Islands           0
# 39        Comorro-Islands           0
# 41           Cook-Islands           0
# 44                 Cyprus           1
# 48               Dominica           0
# 55                Faeroes           0
# 61       French-Polynesia           0
# 67              Gibraltar           0
# 70                Grenada           0
# 71                   Guam           0
# 78              Hong-Kong           5
# 94               Kiribati           0
# 101         Liechtenstein           0
# 102            Luxembourg           0
# ...

# %%
d = {'continente': ["América do Norte e América Central", "América do Sul", "Europa", "África", "Ásia"]}
continentes = pd.DataFrame(data=d, index=[1, 2, 3, 4, 5])
continentes
# Out:
#                            continente
# 1  América do Norte e América Central
# 2                      América do Sul
# 3                              Europa
# 4                              África
# 5                                Ásia

# %%
pais_cont = paises_low_territory.set_index('landmass').join(continentes.set_index(continentes.index))

# %%
pais_cont = pais_cont[['name', 'continente']]
pais_cont
# Out:
#                    name                          continente
# 1              Anguilla  América do Norte e América Central
# 1       Antigua-Barbuda  América do Norte e América Central
# 1              Barbados  América do Norte e América Central
# 1               Bermuda  América do Norte e América Central
# 1  British-Virgin-Isles  América do Norte e América Central
# 1        Cayman-Islands  América do Norte e América Central
# 1              Dominica  América do Norte e América Central
# 1               Grenada  América do Norte e América Central
# 1            Montserrat  América do Norte e América Central
# 1  Netherlands-Antilles  América do Norte e América Central
# 1           Puerto-Rico  América do Norte e América Central
# 1        St-Kitts-Nevis  América do Norte e América Central
# 1              St-Lucia  América do Norte e América Central
# 1            St-Vincent  América do Norte e América Central
# 1   Turks-Cocos-Islands  América do Norte e América Central
# ...

# %%
print('oi')
import numpy as np
# Out:
# oi

# %%
flag_pop = flags[['name', 'population']]

# %%
flag_pop
# Out:
#                name  population
# 0       Afghanistan          16
# 1           Albania           3
# 2           Algeria          20
# 3    American-Samoa           0
# 4           Andorra           0
# ..              ...         ...
# 189   Western-Samoa           0
# 190      Yugoslavia          22
# 191           Zaire          28
# 192          Zambia           6
# 193        Zimbabwe           8
#
# [194 rows x 2 columns]

# %%
def populacao(dataset, nome):
    for item in dataset.values(): #iterando
        print("oi")
        #result = item['population'] #/ (ano_atual - item['ano'])
        #print(result)

# %%
for item in flags:
  print(item)
# Out:
# name
# landmass
# zone
# area
# population
# language
# religion
# bars
# stripes
# colours
# red
# green
# blue
# gold
# white
# black
# orange
# mainhue
# circles
# crosses
# saltires
# quarters
# sunstars
# crescent
# triangle
# icon
# animate
# text
# topleft
# botright

# %%
for index, row in flags.iterrows():
    name = row['name']
    popu = row['population']
    print(f' {name} has {popu*100000} population ')
# Out:
#  Afghanistan has 1600000 population
#  Albania has 300000 population
#  Algeria has 2000000 population
#  American-Samoa has 0 population
#  Andorra has 0 population
#  Angola has 700000 population
#  Anguilla has 0 population
#  Antigua-Barbuda has 0 population
#  Argentina has 2800000 population
#  Argentine has 2800000 population
#  Australia has 1500000 population
#  Austria has 800000 population
#  Bahamas has 0 population
#  Bahrain has 0 population
#  Bangladesh has 9000000 population
#  Barbados has 0 population
#  Belgium has 1000000 population
#  Belize has 0 population
#  Benin has 300000 population
#  Bermuda has 0 population
#  Bhutan has 100000 population
#  Bolivia has 600000 population
#  Botswana has 100000 population
#  Brazil has 11900000 population
#  British-Virgin-Isles has 0 population
#  Brunei has 0 population
#  Bulgaria has 900000 population
#  Burkina has 700000 population
#  Burma has 3500000 population
#  Burundi has 400000 population
# ...

# %%
flags[flags.area.isna()] #linhas que estao com NaN
# Out:
# Empty DataFrame
# Columns: [name, landmass, zone, area, population, language, religion, bars, stripes, colours, red, green, blue, gold, white, black, orange, mainhue, circles, crosses, saltires, quarters, sunstars, crescent, triangle, icon, animate, text, topleft, botright]
# Index: []
#
# [0 rows x 30 columns]

# %%
print("mediana:", flags['area'].median())
# Out:
# mediana: 111.0

# %%
flags['area'].median()
# Out:
# 111.0

# %%
flags['name'].value_counts()
# Out:
# Afghanistan    1
# Sao-Tome       1
# New-Zealand    1
# Nicaragua      1
# Niger          1
#               ..
# Gibraltar      1
# Greece         1
# Greenland      1
# Grenada        1
# Zimbabwe       1
# Name: name, Length: 194, dtype: int64

# %%
flags
# Out:
#                name  landmass  zone  area  population  language  religion  \
# 0       Afghanistan         5     1   648          16        10         2
# 1           Albania         3     1    29           3         6         6
# 2           Algeria         4     1  2388          20         8         2
# 3    American-Samoa         6     3     0           0         1         1
# 4           Andorra         3     1     0           0         6         0
# ..              ...       ...   ...   ...         ...       ...       ...
# 189   Western-Samoa         6     3     3           0         1         1
# 190      Yugoslavia         3     1   256          22         6         6
# 191           Zaire         4     2   905          28        10         5
# 192          Zambia         4     2   753           6        10         5
# 193        Zimbabwe         4     2   391           8        10         5
#
#      bars  stripes  colours  ...  saltires  quarters  sunstars  crescent  \
# ...

# %%
#Boxplot
